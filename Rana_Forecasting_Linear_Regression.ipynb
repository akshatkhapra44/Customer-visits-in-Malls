# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import mean_squared_error
# %matplotlib inline

# %%
dataset = pd.read_csv("Pedestrian_Counting_System_-_Monthly__counts_per_hour_.csv")
print(dataset)
# Out:
#               ID  ... Hourly_Counts
# 0        2887628  ...           300
# 1        2887629  ...           604
# 2        2887630  ...           216
# 3        2887631  ...           627
# 4        2887632  ...           774
# ...          ...  ...           ...
# 3860326  3860327  ...             2
# 3860327  3860328  ...             1
# 3860328  3860329  ...             1
# 3860329  3860330  ...             4
# 3860330  3860331  ...             0
#
# [3860331 rows x 10 columns]

# %% [markdown]
# Check null value in the column

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3860331 entries, 0 to 3860330
# Data columns (total 10 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   ID             int64
#  1   Date_Time      object
#  2   Year           int64
#  3   Month          object
#  4   Mdate          int64
#  5   Day            object
#  6   Time           int64
#  7   Sensor_ID      int64
#  8   Sensor_Name    object
#  9   Hourly_Counts  int64
# dtypes: int64(6), object(4)
# memory usage: 294.5+ MB

# %% [markdown]
# Drop unneeded columns

# %%
dataset= dataset.drop(['ID', 'Date_Time', 'Sensor_Name'], axis= 1)
dataset.head()
# Out:
#    Year     Month  Mdate     Day  Time  Sensor_ID  Hourly_Counts
# 0  2019  November      1  Friday    17         34            300
# 1  2019  November      1  Friday    17         39            604
# 2  2019  November      1  Friday    17         37            216
# 3  2019  November      1  Friday    17         40            627
# 4  2019  November      1  Friday    17         36            774

# %%
dataset.shape
# Out:
# (3860331, 7)

# %%
dataset.describe()
# Out:
#                Year         Mdate          Time     Sensor_ID  Hourly_Counts
# count  3.860331e+06  3.860331e+06  3.860331e+06  3.860331e+06   3.860331e+06
# mean   2.016541e+03  1.575127e+01  1.146438e+01  2.475630e+01   5.258622e+02
# std    3.321525e+00  8.800417e+00  6.941138e+00  1.768704e+01   7.814911e+02
# min    2.009000e+03  1.000000e+00  0.000000e+00  1.000000e+00   0.000000e+00
# 25%    2.014000e+03  8.000000e+00  5.000000e+00  1.000000e+01   4.600000e+01
# 50%    2.017000e+03  1.600000e+01  1.100000e+01  2.100000e+01   1.910000e+02
# 75%    2.019000e+03  2.300000e+01  1.700000e+01  3.700000e+01   6.580000e+02
# max    2.021000e+03  3.100000e+01  2.300000e+01  7.800000e+01   1.597900e+04

# %% [markdown]
# Change the Day and Month to Numeric value to proccess data with the our model.

# %%
dataset = dataset.replace({"Day":{"Monday": 1,"Tuesday": 2,"Wednesday": 3,"Thursday": 4,"Friday": 5,"Saturday": 6,"Sunday": 7}})

# %%
dataset = dataset.replace({"Month":{"January": 1,"February": 2,"March": 3,"April": 4,"May": 5,"June": 6,"July": 7,"August": 8,"September": 9,"October": 10,"November": 11,"December": 12}})

# %% [markdown]
# Display the dataset after chaging day and month to numeric value

# %%
# Display the dataset
dataset.head()
# Out:
#    Year  Month  Mdate  Day  Time  Sensor_ID  Hourly_Counts
# 0  2019     11      1    5    17         34            300
# 1  2019     11      1    5    17         39            604
# 2  2019     11      1    5    17         37            216
# 3  2019     11      1    5    17         40            627
# 4  2019     11      1    5    17         36            774

# %% [markdown]
# Set the dependent and target variable

# %%
x = dataset[['Year', 'Month', 'Mdate', 'Day', 'Time', 'Sensor_ID']]
y = dataset['Hourly_Counts']

# %%
#Split the data with training and test dataset

# %%
#Splitting the data into train,test data 
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 100)

# %% [markdown]
# Implementing the linear model

# %%
#Fitting the Multiple Linear Regression model

# %%
mlr = LinearRegression()  
mlr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print("Intercept: ", mlr.intercept_)
print("Coefficients:")
list(zip(x, mlr.coef_))
# Out:
# Intercept:  24279.535225685577
# Coefficients:
# [('Year', -11.827373576872642),
#  ('Month', -0.8375435635288122),
#  ('Mdate', 0.12072451643701532),
#  ('Day', -8.980873534666491),
#  ('Time', 28.960453564651292),
#  ('Sensor_ID', -7.906588643105855)]

# %% [markdown]
# #Prediction of test set

# %%
y_pred_mlr= mlr.predict(x_test)

# %% [markdown]
# #Predicted values

# %%
print("Prediction for test set: {}".format(y_pred_mlr))
# Out:
# Prediction for test set: [434.70801664 494.63359615 687.91529006 ... 764.21064666 467.97092615
#  513.29506355]

# %% [markdown]
# #Actual value and the predicted value

# %%
mlr_diff = pd.DataFrame({'Actual value': y_test, 'Predicted value': y_pred_mlr})
mlr_diff.head()
# Out:
#          Actual value  Predicted value
# 3243983            24       434.708017
# 2355468           608       494.633596
# 3045623            78       687.915290
# 3593002           484       646.070668
# 2752316            14       187.783539

# %%
meanAbErr = metrics.mean_absolute_error(y_test, y_pred_mlr)
meanSqErr = metrics.mean_squared_error(y_test, y_pred_mlr)
rootMeanSqErr = np.sqrt(metrics.mean_squared_error(y_test, y_pred_mlr))
print('R squared: {:.2f}'.format(mlr.score(x,y)*100))
print('Mean Absolute Error:', meanAbErr)
print('Mean Square Error:', meanSqErr)
print('Root Mean Square Error:', rootMeanSqErr)
# Out:
# R squared: 10.96
# Mean Absolute Error: 492.81772707475363
# Mean Square Error: 543020.5118663762
# Root Mean Square Error: 736.8992548960653

# %% [markdown]
# Conclusion:
# The Multiple Linear Regression model doesn't perform well as R squared is 10.89% of the data fit the regression model. Also, the mean absolute error, mean square error,and the root mean square error are large.
